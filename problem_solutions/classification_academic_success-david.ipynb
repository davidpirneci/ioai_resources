# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/playground-series-s4e6.zip'
# Out:
# Archive:  /content/drive/MyDrive/playground-series-s4e6.zip
# replace sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

target = train["Target"].map({'Graduate': 2, 'Enrolled': 1, 'Dropout': 0})
train = train.drop(['Target', 'id'], axis=1)
test = test.drop(['id'], axis=1)
test.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 1                  1    9500
# 1               1                 1                  1    9238
# 2               1                 1                  1    9238
# 3               1                44                  1    9147
# 4               1                39                  1    9670
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                      39
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           141.0            1                       3
# 1                           128.0            1                       1
# ...

# %%
train.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 1                  1    9238
# 1               1                17                  1    9238
# 2               1                17                  2    9254
# 3               1                 1                  3    9500
# 4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           126.0            1                       1
# 1                           125.0            1                      19
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train, target, test_size=0.2, random_state=42)

# %%
from xgboost import XGBClassifier

# Initialize the XGBClassifier
xgb_classifier = XGBClassifier()

# Train the classifier on the training data
xgb_classifier.fit(X_train, Y_train)

# Make predictions on the testing data
y_pred = xgb_classifier.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8331808677469943

# %%
sample_submission = pd.read_csv("sample_submission.csv")
sample_submission["Target"] = xgb_classifier.predict(test)
sample_submission["Target"] = sample_submission["Target"].map({2: 'Graduate', 1: 'Enrolled', 0: 'Dropout'})
sample_submission.to_csv("submission.csv", index=False)
